# %% [markdown]
# <a href="https://colab.research.google.com/github/snl28/HCJ/blob/main/Class_2_CL_Simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The code trains a SimCLR model on the CIFAR-10 dataset to learn useful image features without labels. It first normalizes the data and applies random augmentations like cropping and flipping. An encoder network turns each image into a 128-dimensional feature vector, and a projection head further processes it. The training loop uses contrastive loss, it makes representations of two augmented views of the same image close together, while pushing apart representations of different images. After training, the encoder creates embeddings for test images, which are reduced to 2D with t-SNE for visualization. The plotted results show clusters that align with different classes, meaning the model learned meaningful and separable features.

# %% [markdown]
# The SimCLR approach aims to learn meaningful representations of images in a self-supervised manner. It does this by maximizing the cosine similarity between representations of augmented views of the same image (positive pairs) and minimizing the cosine similarity between representations of different images (negative pairs). The contrastive loss encourages the encoder to learn representations that are invariant to the applied data augmentations.
#
# The visualization using t-SNE allows us to assess the quality of the learned representations by observing how well the different classes are separated in the low-dimensional space.

# %% [markdown]
# This code demonstrates the implementation of a self-supervised learning approach called SimCLR (Simple Framework for Contrastive Learning of Visual Representations) using the CIFAR-10 dataset. Let's go through the code section by section:
#
# 1. Importing Libraries:
#    - The necessary libraries, including TensorFlow, Keras, Matplotlib, and scikit-learn, are imported.
#
# 2. Loading and Preprocessing Data:
#    - The CIFAR-10 dataset is loaded using `keras.datasets.cifar10.load_data()`.
#    - The pixel values of the training and testing data are normalized to the range [0, 1].
#    - The training data is converted into a TensorFlow Dataset using `tf.data.Dataset.from_tensor_slices()` and batched.
#
# 3. Data Augmentation:
#    - A data augmentation pipeline is defined using `keras.Sequential()` to apply random cropping, flipping, rescaling, and zooming to the input images.
#
# 4. Defining the Encoder Network:
#    - The `create_encoder` function defines the base encoder network using convolutional layers, max pooling, and a global max pooling layer.
#    - The encoder network takes an input image and outputs a 128-dimensional feature representation.
#
# 5. Defining the Projection Head:
#    - The `create_projection_head` function defines the projection head network using dense layers.
#    - The projection head takes the 128-dimensional feature representation from the encoder and projects it to a 128-dimensional space.
#
# 6. Training Loop:
#    - The training loop runs for a specified number of epochs.
#    - For each batch of training data:
#      - The encoder and projection head are applied to the batch of images.
#      - The resulting projected representations are L2-normalized.
#      - The cosine similarity matrix is computed between the normalized representations.
#      - The contrastive loss is calculated using the cosine similarity matrix and temperature scaling.
#      - The gradients of the loss with respect to the weights of the encoder and projection head are computed.
#      - The optimizer is used to update the weights of the encoder and projection head.
#
# 7. Extracting Representations:
#    - After training, the trained encoder is used to extract representations (embeddings) for the test images.
#
# 8. t-SNE Visualization:
#    - The t-SNE algorithm is used to reduce the dimensionality of the learned representations to 2D.
#    - The t-SNE results are plotted using Matplotlib, with each point colored according to its true class label.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# Load and preprocess the CIFAR-10 dataset
(x_train, _), (x_test, y_test) = keras.datasets.cifar10.load_data()
x_train, x_test = x_train.astype('float32') / 255.0, x_test.astype('float32') / 255.0

batch_size = 256

# Convert the training data into a TensorFlow Dataset
train_dataset = tf.data.Dataset.from_tensor_slices(x_train).batch(batch_size)

# Define the data augmentation function
data_augmentation = keras.Sequential([
    layers.RandomCrop(height=32, width=32),
    layers.RandomFlip("horizontal"),
    layers.Rescaling(1./255),
    layers.RandomZoom(0.2),
])

# Define the base encoder network
def create_encoder():
    inputs = layers.Input(shape=(32, 32, 3))
    x = data_augmentation(inputs)
    x = layers.Conv2D(32, 3, activation='relu')(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Conv2D(64, 3, activation='relu')(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Conv2D(128, 3, activation='relu')(x)
    x = layers.GlobalMaxPooling2D()(x)
    outputs = layers.Dense(128)(x)
    return keras.Model(inputs=inputs, outputs=outputs)

# Define the projection head
def create_projection_head():
    inputs = keras.Input(shape=(128,))
    x = layers.Dense(256, activation='relu')(inputs)
    outputs = layers.Dense(128)(x)
    return keras.Model(inputs=inputs, outputs=outputs)

encoder = create_encoder()
projection_head = create_projection_head()

optimizer = keras.optimizers.Adam()
batch_size = 256
epochs = 100
temperature = 0.1

# Custom training loop
for epoch in range(epochs):
    print(f"\nStart of epoch {epoch}")
    for step, x_batch_train in enumerate(train_dataset):
        with tf.GradientTape() as tape:
            # Forward pass
            encoded = encoder(x_batch_train, training=True)
            projected = projection_head(encoded, training=True)
            normalized = tf.math.l2_normalize(projected, axis=1)
            cosine_similarity = tf.matmul(normalized, normalized, transpose_b=True)
            logits = cosine_similarity / temperature
            labels = tf.range(x_batch_train.shape[0])
            loss_value = keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)
            loss_value = tf.reduce_mean(loss_value)

        # Get gradients of loss wrt the weights.
        gradients = tape.gradient(loss_value, encoder.trainable_weights + projection_head.trainable_weights)

        # Update the weights of the encoder and projection head.
        optimizer.apply_gradients(zip(gradients, encoder.trainable_weights + projection_head.trainable_weights))

        if step % 100 == 0:
            print(f"Training loss (for one batch) at step {step}: {float(loss_value)}")

# Extract representations after training
representations = encoder.predict(x_test)

# t-SNE visualization
tsne = TSNE(n_components=2, perplexity=30, n_iter=3000)
tsne_results = tsne.fit_transform(representations)

plt.figure(figsize=(8, 8))
plt.scatter(tsne_results[:, 0], tsne_results[:, 1], c=y_test.flatten(), cmap='rainbow')
plt.title('t-SNE Visualization of Learned Representations')
plt.colorbar()
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 7s 0us/step
#
# Start of epoch 0
# Training loss (for one batch) at step 0: 5.2979254722595215
# Training loss (for one batch) at step 100: 1.1510683298110962
#
# Start of epoch 1
# Training loss (for one batch) at step 0: 0.32189443707466125
# Training loss (for one batch) at step 100: 0.15346452593803406
#
# Start of epoch 2
# Training loss (for one batch) at step 0: 0.1282627433538437
# Training loss (for one batch) at step 100: 0.07164614647626877
#
# Start of epoch 3
# Training loss (for one batch) at step 0: 0.07110291719436646
# Training loss (for one batch) at step 100: 0.05904616042971611
#
# Start of epoch 4
# Training loss (for one batch) at step 0: 0.05795176699757576
# Training loss (for one batch) at step 100: 0.051489800214767456
#
# Start of epoch 5
# Training loss (for one batch) at step 0: 0.048967648297548294
# Training loss (for one batch) at step 100: 0.045205891132354736
#
# Start of epoch 6
# Training loss (for one batch) at step 0: 0.044101517647504807
# Training loss (for one batch) at step 100: 0.0393727570772171
#
# Start of epoch 7
# Training loss (for one batch) at step 0: 0.03936491906642914
# Training loss (for one batch) at step 100: 0.0381338894367218
#
# Start of epoch 8
# Training loss (for one batch) at step 0: 0.03728471323847771
# Training loss (for one batch) at step 100: 0.03408825024962425
#
# Start of epoch 9
# Training loss (for one batch) at step 0: 0.03771539032459259
# Training loss (for one batch) at step 100: 0.03548417240381241
#
# Start of epoch 10
# Training loss (for one batch) at step 0: 0.039727117866277695
# Training loss (for one batch) at step 100: 0.030924160033464432
#
# Start of epoch 11
# Training loss (for one batch) at step 0: 0.03207026794552803
# Training loss (for one batch) at step 100: 0.03006688505411148
#
# Start of epoch 12
# Training loss (for one batch) at step 0: 0.026995744556188583
# Training loss (for one batch) at step 100: 0.02865799143910408
#
# Start of epoch 13
# Training loss (for one batch) at step 0: 0.02892684005200863
# Training loss (for one batch) at step 100: 0.027592074126005173
#
# Start of epoch 14
# Training loss (for one batch) at step 0: 0.028066013008356094
# Training loss (for one batch) at step 100: 0.029507920145988464
#
# Start of epoch 15
# Training loss (for one batch) at step 0: 0.026310505345463753
# Training loss (for one batch) at step 100: 0.02549174427986145
#
# Start of epoch 16
# Training loss (for one batch) at step 0: 0.02654642052948475
# Training loss (for one batch) at step 100: 0.025806887075304985
#
# Start of epoch 17
# Training loss (for one batch) at step 0: 0.0257517471909523
# Training loss (for one batch) at step 100: 0.025248920544981956
#
# Start of epoch 18
# Training loss (for one batch) at step 0: 0.0252542681992054
# Training loss (for one batch) at step 100: 0.024838346987962723
#
# Start of epoch 19
# Training loss (for one batch) at step 0: 0.02492276020348072
# Training loss (for one batch) at step 100: 0.024835243821144104
#
# Start of epoch 20
# Training loss (for one batch) at step 0: 0.022826075553894043
# Training loss (for one batch) at step 100: 0.025602178648114204
#
# Start of epoch 21
# Training loss (for one batch) at step 0: 0.022751430049538612
# Training loss (for one batch) at step 100: 0.02519693598151207
#
# Start of epoch 22
# Training loss (for one batch) at step 0: 0.022916875779628754
# Training loss (for one batch) at step 100: 0.023420678451657295
#
# Start of epoch 23
# Training loss (for one batch) at step 0: 0.022200405597686768
# Training loss (for one batch) at step 100: 0.02211843803524971
#
# Start of epoch 24
# Training loss (for one batch) at step 0: 0.02157982438802719
# Training loss (for one batch) at step 100: 0.022203201428055763
#
# Start of epoch 25
# Training loss (for one batch) at step 0: 0.02153831161558628
# Training loss (for one batch) at step 100: 0.022134263068437576
#
# Start of epoch 26
# Training loss (for one batch) at step 0: 0.02216004952788353
# Training loss (for one batch) at step 100: 0.021476704627275467
#
# Start of epoch 27
# Training loss (for one batch) at step 0: 0.021660462021827698
# Training loss (for one batch) at step 100: 0.02134004794061184
#
# Start of epoch 28
# Training loss (for one batch) at step 0: 0.02110876888036728
# Training loss (for one batch) at step 100: 0.02116822451353073
#
# Start of epoch 29
# Training loss (for one batch) at step 0: 0.021670475602149963
# Training loss (for one batch) at step 100: 0.022066937759518623
#
# Start of epoch 30
# Training loss (for one batch) at step 0: 0.021302934736013412
# Training loss (for one batch) at step 100: 0.02080613188445568
#
# Start of epoch 31
# Training loss (for one batch) at step 0: 0.023253634572029114
# Training loss (for one batch) at step 100: 0.021028509363532066
#
# Start of epoch 32
# Training loss (for one batch) at step 0: 0.020372988656163216
# Training loss (for one batch) at step 100: 0.0201175045222044
#
# Start of epoch 33
# Training loss (for one batch) at step 0: 0.02066582813858986
# Training loss (for one batch) at step 100: 0.02023645117878914
#
# Start of epoch 34
# Training loss (for one batch) at step 0: 0.0206846185028553
# Training loss (for one batch) at step 100: 0.020802531391382217
#
# Start of epoch 35
# Training loss (for one batch) at step 0: 0.020987000316381454
# Training loss (for one batch) at step 100: 0.020132726058363914
#
# Start of epoch 36
# Training loss (for one batch) at step 0: 0.02201130799949169
# Training loss (for one batch) at step 100: 0.020311564207077026
#
# Start of epoch 37
# Training loss (for one batch) at step 0: 0.020552659407258034
# Training loss (for one batch) at step 100: 0.01995920203626156
#
# Start of epoch 38
# Training loss (for one batch) at step 0: 0.020543111488223076
# Training loss (for one batch) at step 100: 0.020639680325984955
#
# Start of epoch 39
# Training loss (for one batch) at step 0: 0.020134519785642624
# Training loss (for one batch) at step 100: 0.019916988909244537
#
# Start of epoch 40
# Training loss (for one batch) at step 0: 0.020858880132436752
# Training loss (for one batch) at step 100: 0.01921779289841652
#
# Start of epoch 41
# Training loss (for one batch) at step 0: 0.021574173122644424
# Training loss (for one batch) at step 100: 0.019385531544685364
#
# Start of epoch 42
# Training loss (for one batch) at step 0: 0.020843230187892914
# Training loss (for one batch) at step 100: 0.020041536539793015
#
# Start of epoch 43
# Training loss (for one batch) at step 0: 0.02159346453845501
# Training loss (for one batch) at step 100: 0.02014913596212864
#
# Start of epoch 44
# Training loss (for one batch) at step 0: 0.019486594945192337
# Training loss (for one batch) at step 100: 0.019387859851121902
#
# Start of epoch 45
# Training loss (for one batch) at step 0: 0.019845856353640556
# Training loss (for one batch) at step 100: 0.019864661619067192
#
# Start of epoch 46
# Training loss (for one batch) at step 0: 0.018908875063061714
# Training loss (for one batch) at step 100: 0.019491998478770256
#
# Start of epoch 47
# Training loss (for one batch) at step 0: 0.019883006811141968
# Training loss (for one batch) at step 100: 0.018634837120771408
#
# Start of epoch 48
# Training loss (for one batch) at step 0: 0.019850734621286392
# Training loss (for one batch) at step 100: 0.019293103367090225
#
# Start of epoch 49
# Training loss (for one batch) at step 0: 0.019584881141781807
# Training loss (for one batch) at step 100: 0.02012217417359352
#
# Start of epoch 50
# Training loss (for one batch) at step 0: 0.01981661468744278
# Training loss (for one batch) at step 100: 0.01941842958331108
#
# Start of epoch 51
# Training loss (for one batch) at step 0: 0.019856000319123268
# Training loss (for one batch) at step 100: 0.018936309963464737
#
# Start of epoch 52
# Training loss (for one batch) at step 0: 0.02005842700600624
# Training loss (for one batch) at step 100: 0.019300198182463646
#
# Start of epoch 53
# Training loss (for one batch) at step 0: 0.019645003601908684
# Training loss (for one batch) at step 100: 0.01869111880660057
#
# Start of epoch 54
# Training loss (for one batch) at step 0: 0.019822940230369568
# Training loss (for one batch) at step 100: 0.019555741921067238
#
# Start of epoch 55
# Training loss (for one batch) at step 0: 0.019421599805355072
# Training loss (for one batch) at step 100: 0.019235393032431602
#
# Start of epoch 56
# Training loss (for one batch) at step 0: 0.019265534356236458
# Training loss (for one batch) at step 100: 0.018990367650985718
#
# Start of epoch 57
# Training loss (for one batch) at step 0: 0.019783364608883858
# Training loss (for one batch) at step 100: 0.01900218054652214
#
# Start of epoch 58
# Training loss (for one batch) at step 0: 0.019343320280313492
# Training loss (for one batch) at step 100: 0.019262805581092834
#
# Start of epoch 59
# Training loss (for one batch) at step 0: 0.01884240284562111
# Training loss (for one batch) at step 100: 0.01936236396431923
#
# Start of epoch 60
# Training loss (for one batch) at step 0: 0.01931476965546608
# Training loss (for one batch) at step 100: 0.018719622865319252
#
# Start of epoch 61
# Training loss (for one batch) at step 0: 0.019336191937327385
# Training loss (for one batch) at step 100: 0.01880766451358795
#
# Start of epoch 62
# Training loss (for one batch) at step 0: 0.018559696152806282
# Training loss (for one batch) at step 100: 0.018642380833625793
#
# Start of epoch 63
# Training loss (for one batch) at step 0: 0.01863989606499672
# Training loss (for one batch) at step 100: 0.018715379759669304
#
# Start of epoch 64
# Training loss (for one batch) at step 0: 0.019117385149002075
# Training loss (for one batch) at step 100: 0.018739858642220497
#
# Start of epoch 65
# Training loss (for one batch) at step 0: 0.018810972571372986
# Training loss (for one batch) at step 100: 0.019117699936032295
#
# Start of epoch 66
# Training loss (for one batch) at step 0: 0.018951086327433586
# Training loss (for one batch) at step 100: 0.018514595925807953
#
# Start of epoch 67
# Training loss (for one batch) at step 0: 0.019657939672470093
# Training loss (for one batch) at step 100: 0.01826317422091961
#
# Start of epoch 68
# Training loss (for one batch) at step 0: 0.018687285482883453
# Training loss (for one batch) at step 100: 0.018405532464385033
#
# Start of epoch 69
# Training loss (for one batch) at step 0: 0.018560439348220825
# Training loss (for one batch) at step 100: 0.01853632740676403
#
# Start of epoch 70
# Training loss (for one batch) at step 0: 0.01854597218334675
# Training loss (for one batch) at step 100: 0.018301136791706085
#
# Start of epoch 71
# Training loss (for one batch) at step 0: 0.018625672906637192
# Training loss (for one batch) at step 100: 0.018683742731809616
#
# Start of epoch 72
# Training loss (for one batch) at step 0: 0.01810651458799839
# Training loss (for one batch) at step 100: 0.01820782758295536
#
# Start of epoch 73
# Training loss (for one batch) at step 0: 0.01845645159482956
# Training loss (for one batch) at step 100: 0.01831548847258091
#
# Start of epoch 74
# Training loss (for one batch) at step 0: 0.018271243199706078
# Training loss (for one batch) at step 100: 0.01817377097904682
#
# Start of epoch 75
# Training loss (for one batch) at step 0: 0.01833369955420494
# Training loss (for one batch) at step 100: 0.01875266805291176
#
# Start of epoch 76
# Training loss (for one batch) at step 0: 0.01915455237030983
# Training loss (for one batch) at step 100: 0.018503133207559586
#
# Start of epoch 77
# Training loss (for one batch) at step 0: 0.018818259239196777
# Training loss (for one batch) at step 100: 0.018107030540704727
#
# Start of epoch 78
# Training loss (for one batch) at step 0: 0.018754655495285988
# Training loss (for one batch) at step 100: 0.018368210643529892
#
# Start of epoch 79
# Training loss (for one batch) at step 0: 0.01882617548108101
# Training loss (for one batch) at step 100: 0.01821754314005375
#
# Start of epoch 80
# Training loss (for one batch) at step 0: 0.0182624701410532
# Training loss (for one batch) at step 100: 0.018605392426252365
#
# Start of epoch 81
# Training loss (for one batch) at step 0: 0.01821519248187542
# Training loss (for one batch) at step 100: 0.018378926441073418
#
# Start of epoch 82
# Training loss (for one batch) at step 0: 0.01768128201365471
# Training loss (for one batch) at step 100: 0.018060103058815002
#
# Start of epoch 83
# Training loss (for one batch) at step 0: 0.018206126987934113
# Training loss (for one batch) at step 100: 0.018400415778160095
#
# Start of epoch 84
# Training loss (for one batch) at step 0: 0.01862124353647232
# Training loss (for one batch) at step 100: 0.01840120740234852
#
# Start of epoch 85
# Training loss (for one batch) at step 0: 0.018119754269719124
# Training loss (for one batch) at step 100: 0.018383024260401726
#
# Start of epoch 86
# Training loss (for one batch) at step 0: 0.017977610230445862
# Training loss (for one batch) at step 100: 0.0179249569773674
#
# Start of epoch 87
# Training loss (for one batch) at step 0: 0.018304258584976196
# Training loss (for one batch) at step 100: 0.018272439017891884
#
# Start of epoch 88
# Training loss (for one batch) at step 0: 0.018356814980506897
# Training loss (for one batch) at step 100: 0.018332533538341522
#
# Start of epoch 89
# Training loss (for one batch) at step 0: 0.017776349559426308
# Training loss (for one batch) at step 100: 0.01787932589650154
#
# Start of epoch 90
# Training loss (for one batch) at step 0: 0.01796768046915531
# Training loss (for one batch) at step 100: 0.017969651147723198
#
# Start of epoch 91
# Training loss (for one batch) at step 0: 0.018455198034644127
# Training loss (for one batch) at step 100: 0.018062476068735123
#
# Start of epoch 92
# Training loss (for one batch) at step 0: 0.01819283701479435
# Training loss (for one batch) at step 100: 0.01791793294250965
#
# Start of epoch 93
# Training loss (for one batch) at step 0: 0.01850072294473648
# Training loss (for one batch) at step 100: 0.01799008809030056
#
# Start of epoch 94
# Training loss (for one batch) at step 0: 0.018145721405744553
# Training loss (for one batch) at step 100: 0.01786617748439312
#
# Start of epoch 95
# Training loss (for one batch) at step 0: 0.018120959401130676
# Training loss (for one batch) at step 100: 0.01855386234819889
#
# Start of epoch 96
# Training loss (for one batch) at step 0: 0.01816147193312645
# Training loss (for one batch) at step 100: 0.017876198515295982
#
# Start of epoch 97
# Training loss (for one batch) at step 0: 0.018088163807988167
# Training loss (for one batch) at step 100: 0.018134625628590584
#
# Start of epoch 98
# Training loss (for one batch) at step 0: 0.01838216371834278
# Training loss (for one batch) at step 100: 0.01759708672761917
#
# Start of epoch 99
# Training loss (for one batch) at step 0: 0.017498213797807693
# Training loss (for one batch) at step 100: 0.018324822187423706
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
